# %% [markdown]
# ![Screenshot 2024-12-28 at 4.28.30 PM.png](attachment:1238f8b3-f112-4484-baad-bb7fb27cc026.png)

# %% [markdown]
# ![Screenshot 2024-12-28 at 4.27.34 PM.png](attachment:dfe7bfef-9123-4930-80b1-3fb2128fd36d.png)

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df = pd.read_csv('car_data.csv')

# %%
df
# Out:
#    Speed  car_age  experience  risk
# 0    200       15         5.0    85
# 1     90       17        13.0    20
# 2    165       12         4.0    93
# 3    110       20         NaN    60
# 4    140        5         3.0    82
# 5    115        2         8.0    10

# %% [markdown]
# ![Copy of water (25).png](attachment:8359cd56-1387-49b6-8988-b8193bbc33e2.png)

# %% [markdown]
# we can do it by using mena / median

# %%
exp_fit = df.experience.median()

# %%
exp_fit
# Out:
# 5.0

# %%
df.experience = df.experience.fillna(exp_fit)

# %%
df
# Out:
#    Speed  car_age  experience  risk
# 0    200       15         5.0    85
# 1     90       17        13.0    20
# 2    165       12         4.0    93
# 3    110       20         5.0    60
# 4    140        5         3.0    82
# 5    115        2         8.0    10

# %% [markdown]
# ![Copy of water (26).png](attachment:20107176-4419-4de2-817c-60305eaafcbd.png)

# %% [markdown]
# first create an object

# %%
reg = linear_model.LinearRegression()

# %% [markdown]
# Let's fit the Model

# %%
reg.fit(df[['Speed','car_age','experience']],df.risk)
# Out:
# LinearRegression()

# %% [markdown]
# ![Copy of water (27).png](attachment:da99ac3a-90a4-41c6-a549-ac61adce568b.png)

# %%
reg.predict([[160,10,5]])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([71.37146872])

# %% [markdown]
# # Ans is- 71
